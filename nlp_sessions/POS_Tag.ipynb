# %% [markdown]
# ### Noun (N)- Daniel, London, table, dog, teacher, pen, city, happiness, hope
# ### Verb (V)- go, speak, run, eat, play, live, walk, have, like, are, is
# ### Adjective(ADJ)- big, happy, green, young, fun, crazy, three
# ### Adverb(ADV)- slowly, quietly, very, always, never, too, well, tomorrow
# ### Preposition (P)- at, on, in, from, with, near, between, about, under
# ### Conjunction (CON)- and, or, but, because, so, yet, unless, since, if
# ### Pronoun(PRO)- I, you, we, they, he, she, it, me, us, them, him, her, this
# ### Interjection (INT)- Ouch! Wow! Great! Help! Oh! Hey! Hi!

# %%
import nltk
import spacy
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('tagsets')
from textblob import TextBlob
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!

# %%
sentence = "My name is Bhavesh"
token = nltk.word_tokenize(sentence)
token
# Out:
# ['My', 'name', 'is', 'Bhavesh']

# %%
nltk.pos_tag(token)
# Out:
# [('My', 'PRP$'), ('name', 'NN'), ('is', 'VBZ'), ('Bhavesh', 'NNP')]

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("My name is Bhavesh") 
# Token and Tag 
for token in doc: 
  print(token, token.pos_)
# Out:
# My ADJ
# name NOUN
# is VERB
# Bhavesh PROPN

# %%
text = "My name is Bhavesh"
blob = TextBlob(text)
print (blob.tags)
# Out:
# [('My', 'PRP$'), ('name', 'NN'), ('is', 'VBZ'), ('Bhavesh', 'NNP')]

# %%
# We can get more details about any POS tag using help funciton of NLTK as follows.
nltk.help.upenn_tagset("PRP$")
# Out:
# PRP$: pronoun, possessive
#     her his mine my our ours their thy your

# %%
nltk.help.upenn_tagset("NN")
# Out:
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...

# %%
nltk.help.upenn_tagset("VBZ")
# Out:
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...

# %%
nltk.help.upenn_tagset("NNP")
# Out:
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...

# %% [markdown]
# <b> Chunking is a process of extracting phrases from unstructured text.
# Instead of just simple tokens which may not represent the actual meaning of the text,
# its advisable to use phrases such as “South Africa”
# as a single word instead of ‘South’ and ‘Africa’ separate words.  </b>

# %%
# https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html
# http://www.softschools.com/examples/grammar/noun_phrases_examples/65/

# %% [markdown]
# Examples of noun phrase as subject:
# The yellow house is for sale.
# The glistening snow covered the field.
#
# Examples of noun phrase as direct object:
# I want a skate board.
# Should we buy the yellow house?
#
# Examples of noun phrase as object of preposition:
# Jeff rode on a skate board.
# Karen lives in the yellow house.
#
# Example of noun phrase as indirect object:
# Lisa gave the little boy a candy.

# %%
nltk.pos_tag(nltk.word_tokenize("The yellow house is for sale"))
# Out:
# [('The', 'DT'),
#  ('yellow', 'JJ'),
#  ('house', 'NN'),
#  ('is', 'VBZ'),
#  ('for', 'IN'),
#  ('sale', 'NN')]

# %%
nltk.help.upenn_tagset("DT")
# Out:
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those

# %%
nltk.help.upenn_tagset("IN")
# Out:
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...

# %%
sentence = "the the little yellow dog barked at the cat"

# %%
# .	Any character except new line  
# *	Match 0 or more repetitions  
# ?	Match 0 or 1 repetitions

# %%
nltk.pos_tag(nltk.word_tokenize("the little yellow dog barked at cat"))
# Out:
# [('the', 'DT'),
#  ('little', 'JJ'),
#  ('yellow', 'JJ'),
#  ('dog', 'NN'),
#  ('barked', 'VBD'),
#  ('at', 'IN'),
#  ('cat', 'NN')]

# %%
grammar = ('''
    NP: {<DT>?<JJ>*<NN>} # NP
    ''')
# grammar = ('''
#     NP: {<NN>} # NP
#     ''')

# %%
chunkParser = nltk.RegexpParser(grammar)
tagged = nltk.pos_tag(nltk.word_tokenize(sentence))
tagged
# Out:
# [('the', 'DT'),
#  ('the', 'DT'),
#  ('little', 'JJ'),
#  ('yellow', 'JJ'),
#  ('dog', 'NN'),
#  ('barked', 'VBD'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('cat', 'NN')]

# %%
result = chunkParser.parse(tagged)
for subtree in result.subtrees():
  if subtree.label() == 'NP':
    t = subtree
    t = ' '.join(word for word, pos in t.leaves())
    print(t)
# Out:
# the little yellow dog
# the cat

# %%
tagged1 = nltk.pos_tag(nltk.word_tokenize("A prison riot left six members of staff needing hospital treatment earlier this month, the BBC learns"))
tagged1
# Out:
# [('A', 'DT'),
#  ('prison', 'NN'),
#  ('riot', 'NN'),
#  ('left', 'VBD'),
#  ('six', 'CD'),
#  ('members', 'NNS'),
#  ('of', 'IN'),
#  ('staff', 'NN'),
#  ('needing', 'VBG'),
#  ('hospital', 'NN'),
#  ('treatment', 'NN'),
#  ('earlier', 'RBR'),
#  ('this', 'DT'),
#  ('month', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('BBC', 'NNP'),
#  ('learns', 'NNS')]

# %%
def prepareForNLP(text):
	sentences = nltk.sent_tokenize(text)
	sentences = [nltk.word_tokenize(sent) for sent in sentences]
	sentences = [nltk.pos_tag(sent) for sent in sentences]
	return sentences

def chunk(sentence):
	chunkToExtract = """
	NP: {<NNP>*}
		{<DT>?<JJ>?<NNS>}
		{<NN><NN>}"""
	parser = nltk.RegexpParser(chunkToExtract)
	result = parser.parse(sentence)
	for subtree in result.subtrees():
		if subtree.label() == 'NP':
			t = subtree
			t = ' '.join(word for word, pos in t.leaves())
			print(t)

# %%
sentences = prepareForNLP("""
A prison riot left six members of staff needing 
hospital treatment earlier this month, the BBC learns
""")
for sentence in sentences:
	chunk(sentence)
# Out:
# prison riot
# members
# hospital treatment
# BBC
# learns

# %%
doc = nlp("Next week I'll be in Madrid.")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Next week DATE
# Madrid GPE

# %%
doc = nlp("""I just bought 2 shares at 9 a.m. because the stock went 
          up 30% in just 2 days according to the BSE Stock Exchange""")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# 2 CARDINAL
# 9 a.m. TIME
# 30% PERCENT
# just 2 days DATE
# the BSE Stock Exchange ORG

# %%
# Process whole documents 
text = ("""My name is Bhavesh Bhatt.  
I enjoy creating videos on machine learning checkout
all my other article by going to my YouTube website.""") 
  
doc = nlp(text) 
  
# Token and Tag 
for token in doc: 
  print(token, token.pos_) 
  
# You want list of Verb tokens 
print("Verbs:", [token.text for token in doc if token.pos_ == "VERB"])
# Out:
# My ADJ
# name NOUN
# is VERB
# Bhavesh PROPN
# Bhatt PROPN
# . PUNCT
#
#  SPACE
# I PRON
# enjoy VERB
# creating VERB
# videos NOUN
# on ADP
# machine NOUN
# learning VERB
# checkout NOUN
#
#  SPACE
# all ADJ
# my ADJ
# other ADJ
# article NOUN
# by ADP
# going VERB
# to ADP
# my ADJ
# YouTube PROPN
# website NOUN
# . PUNCT
# Verbs: ['is', 'enjoy', 'creating', 'learning', 'going']

# %%
for token in doc: 
  print(token, token.lemma_)
# Out:
# My -PRON-
# name name
# is be
# Bhavesh bhavesh
# Bhatt bhatt
# . .
#
#
#
# I -PRON-
# enjoy enjoy
# creating create
# videos video
# on on
# machine machine
# learning learn
# checkout checkout
#
#
#
# all all
# my -PRON-
# other other
# article article
# by by
# going go
# to to
# my -PRON-
# YouTube youtube
# website website
# . .

# %%
text = ("""My name is Bhavesh Bhatt.I like making YouTube videos.""")
doc = nlp(text)

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Bhavesh Bhatt PERSON
# YouTube ORG

# %%
doc = nlp("Wall Street Journal just published an interesting piece on crypto currencies")
for chunk in doc.noun_chunks:
    print(chunk.text, chunk.label_, chunk.root.text)
# Out:
# Wall Street Journal NP Journal
# an interesting piece NP piece
# crypto currencies NP currencies
